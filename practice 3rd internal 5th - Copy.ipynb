# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
nm=pd.read_csv("C:/Users/naras/OneDrive/Desktop/Boston.csv")
nm
# OR
#TO DOING IN EXCELL
##nc={
   # #"names" : ['narasimha','sneha','mohan','uday','ruchitha'],
   ##'gender':['male','male','male','male','femail'],
   ##'age':[22,21,18,19,17]
##}
#nc

#converting pandas to dataframe 
##nc1=pd.DataFrame(data=nc)
##nc1
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
nm.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
nm.tail()
# Out:
#      Unnamed: 0     crim   zn  indus  chas    nox     rm   age     dis  rad  \
# 501         502  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# 501  273     21.0  391.99   9.67  22.4
# 502  273     21.0  396.90   9.08  20.6
# 503  273     21.0  396.90   5.64  23.9
# 504  273     21.0  393.45   6.48  22.0
# 505  273     21.0  396.90   7.88  11.9

# %%
nm.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
nm.duplicated().sum()
# Out:
# 0

# %%
nm.shape
# Out:
# (506, 15)

# %%
nm.isnull().sum()
# Out:
# Unnamed: 0    0
# crim          0
# zn            0
# indus         0
# chas          0
# nox           0
# rm            0
# age           0
# dis           0
# rad           0
# tax           0
# ptratio       0
# black         0
# lstat         0
# medv          0
# dtype: int64

# %%
#filling the nan values
nm['country'].fillna('not displayed',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#replace  on categorical using mode
mode=nm['country'].mode().values[0]
mode
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
nm['country'].replace(np.nan,mode,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
nm.dtypes
# Out:
# Unnamed: 0      int64
# crim          float64
# zn            float64
# indus         float64
# chas            int64
# nox           float64
# rm            float64
# age           float64
# dis           float64
# rad             int64
# tax             int64
# ptratio       float64
# black         float64
# lstat         float64
# medv          float64
# dtype: object

# %%
nm['chas']=nm['chas'].astype('object')

# %%
nm['rad']=nm['rad'].astype('string')

# %%
nm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   crim        506 non-null    float64
#  2   zn          506 non-null    float64
#  3   indus       506 non-null    float64
#  4   chas        506 non-null    object
#  5   nox         506 non-null    float64
#  6   rm          506 non-null    float64
#  7   age         506 non-null    float64
#  8   dis         506 non-null    float64
#  9   rad         506 non-null    string
#  10  tax         506 non-null    int64
#  11  ptratio     506 non-null    float64
#  12  black       506 non-null    float64
#  13  lstat       506 non-null    float64
#  14  medv        506 non-null    float64
# dtypes: float64(11), int64(2), object(1), string(1)
# memory usage: 59.4+ KB

# %%
nm.columns
# Out:
# Index(['Unnamed: 0', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis',
#        'rad', 'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
max=nm['rm'].max()
max
# Out:
# 8.78

# %%
min=nm['rm'].max()
min
# Out:
# 8.78

# %%
# finding quantile
q=nm['age'].quantile(0.15)
q
# Out:
# 32.2

# %% [markdown]
# # univatiate

# %%
plt.hist(data=nm,x='rm')
plt.show()

# %% [markdown]
# # by-variate

# %%
nm.plot(kind='bar')
plt.show()

# %%
plt.scatter(data=nm,x='rm',y='age')
plt.show()

# %%
sns.pairplot(data=nm)
plt.show()

# %% [markdown]
# # CORELATION MATRICS

# %%
import seaborn as sns
nml=nm.corr().round(2)
plt.figure(figsize=(12,8))
sns.heatmap(nml,annot=True)
# Out:
# C:\Users\naras\AppData\Local\Temp\ipykernel_27140\3456023092.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   nml=nm.corr().round(2)
# <Axes: >

# %%
x=[['rm']]

# %%
y=[['medv']]

# %%
plt.scatter(data=nm,x='rm',y='medv')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
#
# NameError: name 'train_test_split' is not defined
