# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/naras/OneDrive/Desktop/Boston.csv")
df
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis',
#        'rad', 'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
corr_mat=df.corr().round(2)
plt.figure(figsize=(12,8))
sns.heatmap(corr_mat,annot=True)
# Out:
# <Axes: >

# %%
x=df[['lstat']]
x
# Out:
#      lstat
# 0     4.98
# 1     9.14
# 2     4.03
# 3     2.94
# 4     5.33
# ..     ...
# 501   9.67
# 502   9.08
# 503   5.64
# 504   6.48
# 505   7.88
#
# [506 rows x 1 columns]

# %%
y=df[['medv']]
y.shape
# Out:
# (506, 1)

# %%
sns.scatterplot(data=df,x='lstat',y='medv')
# Out:
# <Axes: xlabel='lstat', ylabel='medv'>

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (404, 1)
# (102, 1)
# (404, 1)
# (102, 1)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[-0.92441715]])

# %%
y_pred=model.predict(x_train)
y_pred
# Out:
# array([[28.96411475],
#        [27.99347674],
#        [ 5.853686  ],
#        [22.92767076],
#        [18.4719801 ],
#        [29.25068407],
#        [22.17889287],
#        [27.24469885],
#        [31.4138202 ],
#        [25.97824735],
#        [14.44152132],
#        [28.35399943],
#        [27.13376879],
#        [31.68190117],
#        [25.33115535],
#        [23.52854191],
#        [32.50463243],
#        [27.45731479],
#        [25.1185394 ],
#        [17.03913351],
#        [29.86079938],
#        [21.21749903],
#        [25.54377129],
#        [22.39150881],
#        [26.40347924],
#        [25.94127067],
#        [20.75529046],
#        [29.44481167],
#        [21.25447572],
#        [24.75801672],
#        [28.59434789],
#        [10.59594598],
#        [27.66068657],
#        [27.92876754],
#        [ 9.54211043],
#        [16.76180837],
#        [27.34638474],
#        [18.42575924],
#        [29.18597486],
#        [17.2702378 ],
#        [17.08535437],
# ...

# %%
model.coef_
# Out:
# array([[-0.92441715]])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
print('mean_absolute_error',mean_absolute_error(y_train,y_pred))
print('mean_squared_error',np.sqrt(mean_squared_error(y_train,y_pred)))
print('r2_score',r2_score(y_train,y_pred))
# Out:
# mean_absolute_error 4.384375153324861
# mean_squared_error 6.032391369195223
# r2_score 0.5495280791456811

# %% [markdown]
# # multiple linearregression

# %%
x=df[['rm']]
x
# Out:
#         rm
# 0    6.575
# 1    6.421
# 2    7.185
# 3    6.998
# 4    7.147
# ..     ...
# 501  6.593
# 502  6.120
# 503  6.976
# 504  6.794
# 505  6.030
#
# [506 rows x 1 columns]

# %%
x_train_pred=model.predict(x_train)
x.shape
# Out:
# (506, 1)

# %%
y=df[['medv']]
y.shape
# Out:
# (506, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print('mean_absolute_error',mean_absolute_error(y_train,y_pred))
print('mean_squared_error',np.sqrt(mean_squared_error(y_train,y_pred)))
print('r2_score',r2_score(y_train,y_pred))
# Out:
# mean_absolute_error 4.384375153324861
# mean_squared_error 6.032391369195223
# r2_score 0.5495280791456811
