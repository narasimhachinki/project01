# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import rcParams
rcParams['figure.figsize'] = 12,6
plt.style.use('ggplot')

# %%
df=pd.read_csv("C:/Users/naras/OneDrive/Desktop/hotel_bookings.csv.zip")
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.drop(['lead_time','arrival_date_year','adults'],axis=1, inplace=True)
df.head()
# Out:
#           hotel  is_canceled arrival_date_month  arrival_date_week_number  \
# 0  Resort Hotel            0               July                        27
# 1  Resort Hotel            0               July                        27
# 2  Resort Hotel            0               July                        27
# 3  Resort Hotel            0               July                        27
# 4  Resort Hotel            0               July                        27
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
# 1                          1                        0                     0
# 2                          1                        0                     1
# 3                          1                        0                     1
# 4                          1                        0                     2
#
#    children  babies meal  ... deposit_type  agent company  \
# ...

# %%
table1=pd.pivot_table(data=df,index=['hotel'])
table1
# Out:
# C:\Users\naras\AppData\Local\Temp\ipykernel_22616\1648567344.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   table1=pd.pivot_table(data=df,index=['hotel'])
#                      adr       agent  arrival_date_day_of_month  \
# hotel
# City Hotel    105.304465   28.144721                  15.786625
# Resort Hotel   94.952930  217.571725                  15.821243
#
#               arrival_date_week_number    babies  booking_changes  children  \
# hotel
# City Hotel                   27.177449  0.004941         0.187369  0.091370
# Resort Hotel                 27.140864  0.013904         0.287968  0.128682
#
#                  company  days_in_waiting_list  is_canceled  \
# hotel
# City Hotel    145.271618              3.226774     0.417270
# Resort Hotel  241.486165              0.527758     0.277634
#
# ...

# %%
table1.plot(kind='bar')
# Out:
# <Axes: xlabel='hotel'>
