# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
iris=sns.load_dataset('iris')#dataset
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.nunique()
# Out:
# sepal_length    35
# sepal_width     23
# petal_length    43
# petal_width     22
# species          3
# dtype: int64

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
#nsn.pairplot(iris_data) or
sns.pairplot(iris,diag_kind='kde')

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
iris.duplicated().sum().sum()
# Out:
# 1

# %%
sns.pairplot(iris)

# %%
new_iris=iris[['petal_width','petal_length']]
new_iris
# Out:
#      petal_width  petal_length
# 0            0.2           1.4
# 1            0.2           1.4
# 2            0.2           1.3
# 3            0.2           1.5
# 4            0.2           1.4
# ..           ...           ...
# 145          2.3           5.2
# 146          1.9           5.0
# 147          2.0           5.2
# 148          2.3           5.4
# 149          1.8           5.1
#
# [150 rows x 2 columns]

# %%
x=new_iris['petal_width']
y=new_iris['petal_length']

# %%
plt.scatter(x,y)
plt.xlabel('petal_width')
plt.title('scatter plot to show the relationship')
# Out:
# Text(0.5, 1.0, 'scatter plot to show the relationship')

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0,)

# %%
x_train
# Out:
# 137    1.8
# 84     1.5
# 27     0.2
# 127    1.8
# 132    2.2
#       ...
# 9      0.1
# 103    1.8
# 67     1.0
# 117    2.2
# 47     0.2
# Name: petal_width, Length: 120, dtype: float64

# %%
x_train=np.array(x_train).reshape(-1,1)#reshape

# %%
x_train
# Out:
# array([[1.8],
#        [1.5],
#        [0.2],
#        [1.8],
#        [2.2],
#        [1.4],
#        [0.3],
#        [1.6],
#        [1.5],
#        [1.2],
#        [2.1],
#        [0.2],
#        [2.3],
#        [0.6],
#        [0.2],
#        [1. ],
#        [1.8],
#        [2.5],
#        [1.5],
#        [1.8],
#        [1.1],
#        [2.3],
#        [1.6],
#        [1.1],
#        [1.8],
#        [1.5],
#        [1.7],
#        [1.9],
#        [1.4],
#        [2. ],
#        [1.6],
#        [0.2],
#        [1.9],
#        [1.3],
#        [1.3],
#        [1.3],
#        [1.4],
#        [1.8],
#        [0.2],
#        [0.1],
#        [1.9],
#        [1.2],
#        [0.2],
#        [0.4],
#        [1.5],
#        [0.2],
#        [1.8],
#        [1.1],
#        [0.3],
#        [1.5],
#        [2.5],
#        [1.3],
#        [0.1],
#        [2.1],
#        [2.3],
#        [2.2],
#        [2.1],
#        [0.2],
#        [0.2],
#        [2. ],
#        [2.1],
#        [0.3],
# ...

# %%
x_test=np.array(x_test).reshape(-1,1)#reshape the x_test into 2d array
x_test
# Out:
# array([[2.4],
#        [1. ],
#        [0.2],
#        [1.8],
#        [0.2],
#        [2.5],
#        [0.3],
#        [1.5],
#        [1.4],
#        [1.3],
#        [1.4],
#        [1.5],
#        [1.2],
#        [1.5],
#        [1.4],
#        [0.1],
#        [1.5],
#        [1.2],
#        [0.3],
#        [0.4],
#        [2. ],
#        [1.5],
#        [0.2],
#        [0.2],
#        [1.8],
#        [0.2],
#        [0.4],
#        [1.3],
#        [1. ],
#        [0.4]])

# %%
from sklearn.linear_model import LinearRegression
linear=LinearRegression()
model=linear.fit(x_train,y_train)

# %%
model.coef_
# Out:
# array([2.22883109])

# %%
model.intercept_
# Out:
# 1.0706563724553733

# %%
#sns.regplot(x=x,y=y)

# %%
y_train_pred=linear.predict(x_train)
y_train
# Out:
# 137    5.5
# 84     4.5
# 27     1.5
# 127    4.9
# 132    5.6
#       ...
# 9      1.5
# 103    5.6
# 67     4.1
# 117    6.7
# 47     1.4
# Name: petal_length, Length: 120, dtype: float64

# %%
plt.scatter(x=x_train, y=y_train)
plt.plot(x_train,y_train_pred,color='g')

# %%
y_test_pred=linear.predict(x_test)
y_test
# Out:
# 114    5.1
# 62     4.0
# 33     1.4
# 107    6.3
# 7      1.5
# 100    6.0
# 40     1.3
# 86     4.7
# 76     4.8
# 71     4.0
# 134    5.6
# 51     4.5
# 73     4.7
# 54     4.6
# 63     4.7
# 37     1.4
# 78     4.5
# 90     4.4
# 45     1.4
# 16     1.3
# 121    4.9
# 66     4.5
# 24     1.9
# 8      1.4
# 126    4.8
# 22     1.0
# 44     1.9
# 97     4.3
# 93     3.3
# 26     1.6
# Name: petal_length, dtype: float64

# %%
plt.scatter(x=x_test, y=y_test)
plt.plot(x_train,y_train_pred,color='g')
